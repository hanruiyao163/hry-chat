# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

embeddings = OpenAIEmbeddings(
    model="doubao-embedding-vision-250615", base_url="https://ark.cn-beijing.volces.com/api/v3", api_key="38177d00-8203-4492-a74d-901264a6e90e"
)

embeddings.embed_documents(['nihao'])
# Out:
# c:\Users\hanma\Programming\hry-chat\backend\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 7
#       1 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#       3 embeddings = OpenAIEmbeddings(
#       4     model="doubao-embedding-vision-250615", base_url="https://ark.cn-beijing.volces.com/api/v3", api_key="38177d00-8203-4492-a74d-901264a6e90e"
#       5 )
# ----> 7 embeddings.embed_documents(['nihao'])
#
# File c:\Users\hanma\Programming\hry-chat\backend\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:709, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
# ...
